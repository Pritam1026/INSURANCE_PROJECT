# %%
import pymongo
import pandas as pd
import numpy as np

# %%
uri="mongodb+srv://singhpritam382:rYCq7TiYelUQ9yYN@cluster0.hm3g8y3.mongodb.net/?retryWrites=true&w=majority"

# %%
client=pymongo.MongoClient(uri)

# %%
print(client)
# Out:
# MongoClient(host=['ac-qluiruz-shard-00-01.hm3g8y3.mongodb.net:27017', 'ac-qluiruz-shard-00-02.hm3g8y3.mongodb.net:27017', 'ac-qluiruz-shard-00-00.hm3g8y3.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-fcb2to-shard-0', tls=True)

# %%
database_name="INSURANCE"
collection_name="INSURANCE_PROJECT"

# %%
data=client[database_name][collection_name].find()

# %%
print(data)
# Out:
# <pymongo.cursor.Cursor object at 0x0000023C66AD5310>

# %%
list(data)
# Out:
# [{'_id': ObjectId('6558c4c5d93220317ba8a18b'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 27.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 16884.92},
#  {'_id': ObjectId('6558c4c5d93220317ba8a18c'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 33.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1725.55},
#  {'_id': ObjectId('6558c4c5d93220317ba8a18d'),
#   'age': 28,
#   'sex': 'male',
#   'bmi': 33.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4449.46},
#  {'_id': ObjectId('6558c4c5d93220317ba8a18e'),
#   'age': 33,
#   'sex': 'male',
#   'bmi': 22.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 21984.47},
#  {'_id': ObjectId('6558c4c5d93220317ba8a18f'),
#   'age': 32,
#   'sex': 'male',
#   'bmi': 28.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3866.86},
#  {'_id': ObjectId('6558c4c5d93220317ba8a190'),
#   'age': 31,
#   'sex': 'female',
#   'bmi': 25.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3756.62},
#  {'_id': ObjectId('6558c4c5d93220317ba8a191'),
#   'age': 46,
#   'sex': 'female',
#   'bmi': 33.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8240.59},
#  {'_id': ObjectId('6558c4c5d93220317ba8a192'),
#   'age': 37,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7281.51},
#  {'_id': ObjectId('6558c4c5d93220317ba8a193'),
#   'age': 37,
#   'sex': 'male',
#   'bmi': 29.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6406.41},
#  {'_id': ObjectId('6558c4c5d93220317ba8a194'),
#   'age': 60,
#   'sex': 'female',
#   'bmi': 25.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 28923.14},
#  {'_id': ObjectId('6558c4c5d93220317ba8a195'),
#   'age': 25,
#   'sex': 'male',
#   'bmi': 26.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2721.32},
#  {'_id': ObjectId('6558c4c5d93220317ba8a196'),
#   'age': 62,
#   'sex': 'female',
#   'bmi': 26.3,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 27808.73},
#  {'_id': ObjectId('6558c4c5d93220317ba8a197'),
#   'age': 23,
#   'sex': 'male',
#   'bmi': 34.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1826.84},
#  {'_id': ObjectId('6558c4c5d93220317ba8a198'),
#   'age': 56,
#   'sex': 'female',
#   'bmi': 39.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11090.72},
#  {'_id': ObjectId('6558c4c5d93220317ba8a199'),
#   'age': 27,
#   'sex': 'male',
#   'bmi': 42.1,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 39611.76},
#  {'_id': ObjectId('6558c4c5d93220317ba8a19a'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 24.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1837.24},
#  {'_id': ObjectId('6558c4c5d93220317ba8a19b'),
#   'age': 52,
#   'sex': 'female',
#   'bmi': 30.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 10797.34},
#  {'_id': ObjectId('6558c4c5d93220317ba8a19c'),
#   'age': 23,
#   'sex': 'male',
#   'bmi': 23.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2395.17},
#  {'_id': ObjectId('6558c4c5d93220317ba8a19d'),
#   'age': 56,
#   'sex': 'male',
#   'bmi': 40.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10602.39},
#  {'_id': ObjectId('6558c4c5d93220317ba8a19e'),
#   'age': 30,
#   'sex': 'male',
#   'bmi': 35.3,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 36837.47},
#  {'_id': ObjectId('6558c4c5d93220317ba8a19f'),
#   'age': 60,
#   'sex': 'female',
#   'bmi': 36.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13228.85},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a0'),
#   'age': 30,
#   'sex': 'female',
#   'bmi': 32.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4149.74},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a1'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 34.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1137.01},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a2'),
#   'age': 34,
#   'sex': 'female',
#   'bmi': 31.9,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 37701.88},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a3'),
#   'age': 37,
#   'sex': 'male',
#   'bmi': 28.0,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6203.9},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a4'),
#   'age': 59,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 14001.13},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a5'),
#   'age': 63,
#   'sex': 'female',
#   'bmi': 23.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 14451.84},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a6'),
#   'age': 55,
#   'sex': 'female',
#   'bmi': 32.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 12268.63},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a7'),
#   'age': 23,
#   'sex': 'male',
#   'bmi': 17.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2775.19},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a8'),
#   'age': 31,
#   'sex': 'male',
#   'bmi': 36.3,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 38711.0},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1a9'),
#   'age': 22,
#   'sex': 'male',
#   'bmi': 35.6,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 35585.58},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1aa'),
#   'age': 18,
#   'sex': 'female',
#   'bmi': 26.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2198.19},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ab'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 28.6,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4687.8},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ac'),
#   'age': 63,
#   'sex': 'male',
#   'bmi': 28.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 13770.1},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ad'),
#   'age': 28,
#   'sex': 'male',
#   'bmi': 36.4,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 51194.56},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ae'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 20.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 1625.43},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1af'),
#   'age': 62,
#   'sex': 'female',
#   'bmi': 33.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 15612.19},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b0'),
#   'age': 26,
#   'sex': 'male',
#   'bmi': 20.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2302.3},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b1'),
#   'age': 35,
#   'sex': 'male',
#   'bmi': 36.7,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 39774.28},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b2'),
#   'age': 60,
#   'sex': 'male',
#   'bmi': 39.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 48173.36},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b3'),
#   'age': 24,
#   'sex': 'female',
#   'bmi': 26.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3046.06},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b4'),
#   'age': 31,
#   'sex': 'female',
#   'bmi': 36.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4949.76},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b5'),
#   'age': 41,
#   'sex': 'male',
#   'bmi': 21.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 6272.48},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b6'),
#   'age': 37,
#   'sex': 'female',
#   'bmi': 30.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 6313.76},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b7'),
#   'age': 38,
#   'sex': 'male',
#   'bmi': 37.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6079.67},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b8'),
#   'age': 55,
#   'sex': 'male',
#   'bmi': 37.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 20630.28},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1b9'),
#   'age': 18,
#   'sex': 'female',
#   'bmi': 38.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3393.36},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ba'),
#   'age': 28,
#   'sex': 'female',
#   'bmi': 34.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3556.92},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1bb'),
#   'age': 60,
#   'sex': 'female',
#   'bmi': 24.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12629.9},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1bc'),
#   'age': 36,
#   'sex': 'male',
#   'bmi': 35.2,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 38709.18},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1bd'),
#   'age': 18,
#   'sex': 'female',
#   'bmi': 35.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2211.13},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1be'),
#   'age': 21,
#   'sex': 'female',
#   'bmi': 33.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3579.83},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1bf'),
#   'age': 48,
#   'sex': 'male',
#   'bmi': 28.0,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 23568.27},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c0'),
#   'age': 36,
#   'sex': 'male',
#   'bmi': 34.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 37742.58},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c1'),
#   'age': 40,
#   'sex': 'female',
#   'bmi': 28.7,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8059.68},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c2'),
#   'age': 58,
#   'sex': 'male',
#   'bmi': 37.0,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 47496.49},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c3'),
#   'age': 58,
#   'sex': 'female',
#   'bmi': 31.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13607.37},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c4'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 31.7,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 34303.17},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c5'),
#   'age': 53,
#   'sex': 'female',
#   'bmi': 22.9,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 23244.79},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c6'),
#   'age': 34,
#   'sex': 'female',
#   'bmi': 37.3,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5989.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c7'),
#   'age': 43,
#   'sex': 'male',
#   'bmi': 27.4,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 8606.22},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c8'),
#   'age': 25,
#   'sex': 'male',
#   'bmi': 33.7,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4504.66},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1c9'),
#   'age': 64,
#   'sex': 'male',
#   'bmi': 24.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 30166.62},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ca'),
#   'age': 28,
#   'sex': 'female',
#   'bmi': 25.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4133.64},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1cb'),
#   'age': 20,
#   'sex': 'female',
#   'bmi': 22.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 14711.74},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1cc'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 28.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1743.21},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1cd'),
#   'age': 61,
#   'sex': 'female',
#   'bmi': 39.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 14235.07},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ce'),
#   'age': 40,
#   'sex': 'male',
#   'bmi': 26.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6389.38},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1cf'),
#   'age': 40,
#   'sex': 'female',
#   'bmi': 36.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5920.1},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d0'),
#   'age': 28,
#   'sex': 'male',
#   'bmi': 24.0,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 17663.14},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d1'),
#   'age': 27,
#   'sex': 'female',
#   'bmi': 24.8,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 16577.78},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d2'),
#   'age': 31,
#   'sex': 'male',
#   'bmi': 28.5,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6799.46},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d3'),
#   'age': 53,
#   'sex': 'female',
#   'bmi': 28.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11741.73},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d4'),
#   'age': 58,
#   'sex': 'male',
#   'bmi': 32.0,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11946.63},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d5'),
#   'age': 44,
#   'sex': 'male',
#   'bmi': 27.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7726.85},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d6'),
#   'age': 57,
#   'sex': 'male',
#   'bmi': 34.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11356.66},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d7'),
#   'age': 29,
#   'sex': 'female',
#   'bmi': 29.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3947.41},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d8'),
#   'age': 21,
#   'sex': 'male',
#   'bmi': 35.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1532.47},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1d9'),
#   'age': 22,
#   'sex': 'female',
#   'bmi': 39.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2755.02},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1da'),
#   'age': 41,
#   'sex': 'female',
#   'bmi': 33.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6571.02},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1db'),
#   'age': 31,
#   'sex': 'male',
#   'bmi': 26.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4441.21},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1dc'),
#   'age': 45,
#   'sex': 'female',
#   'bmi': 38.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7935.29},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1dd'),
#   'age': 22,
#   'sex': 'male',
#   'bmi': 37.6,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 37165.16},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1de'),
#   'age': 48,
#   'sex': 'female',
#   'bmi': 41.2,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11033.66},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1df'),
#   'age': 37,
#   'sex': 'female',
#   'bmi': 34.8,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 39836.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e0'),
#   'age': 45,
#   'sex': 'male',
#   'bmi': 22.9,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 21098.55},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e1'),
#   'age': 57,
#   'sex': 'female',
#   'bmi': 31.2,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 43578.94},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e2'),
#   'age': 56,
#   'sex': 'female',
#   'bmi': 27.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11073.18},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e3'),
#   'age': 46,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8026.67},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e4'),
#   'age': 55,
#   'sex': 'female',
#   'bmi': 27.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11082.58},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e5'),
#   'age': 21,
#   'sex': 'female',
#   'bmi': 39.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2026.97},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e6'),
#   'age': 53,
#   'sex': 'female',
#   'bmi': 24.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10942.13},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e7'),
#   'age': 59,
#   'sex': 'male',
#   'bmi': 29.8,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 30184.94},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e8'),
#   'age': 35,
#   'sex': 'male',
#   'bmi': 34.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5729.01},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1e9'),
#   'age': 64,
#   'sex': 'female',
#   'bmi': 31.3,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 47291.06},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ea'),
#   'age': 28,
#   'sex': 'female',
#   'bmi': 37.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3766.88},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1eb'),
#   'age': 54,
#   'sex': 'female',
#   'bmi': 30.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12105.32},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ec'),
#   'age': 55,
#   'sex': 'male',
#   'bmi': 38.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 10226.28},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ed'),
#   'age': 56,
#   'sex': 'male',
#   'bmi': 20.0,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 22412.65},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ee'),
#   'age': 38,
#   'sex': 'male',
#   'bmi': 19.3,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 15820.7},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ef'),
#   'age': 41,
#   'sex': 'female',
#   'bmi': 31.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6186.13},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f0'),
#   'age': 30,
#   'sex': 'male',
#   'bmi': 25.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3645.09},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f1'),
#   'age': 18,
#   'sex': 'female',
#   'bmi': 30.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 21344.85},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f2'),
#   'age': 61,
#   'sex': 'female',
#   'bmi': 29.9,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 30942.19},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f3'),
#   'age': 34,
#   'sex': 'female',
#   'bmi': 27.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5003.85},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f4'),
#   'age': 20,
#   'sex': 'male',
#   'bmi': 28.0,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 17560.38},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f5'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 28.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2331.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f6'),
#   'age': 26,
#   'sex': 'male',
#   'bmi': 30.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3877.3},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f7'),
#   'age': 29,
#   'sex': 'male',
#   'bmi': 27.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2867.12},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f8'),
#   'age': 63,
#   'sex': 'male',
#   'bmi': 35.1,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 47055.53},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1f9'),
#   'age': 54,
#   'sex': 'male',
#   'bmi': 33.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10825.25},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1fa'),
#   'age': 55,
#   'sex': 'female',
#   'bmi': 29.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11881.36},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1fb'),
#   'age': 37,
#   'sex': 'male',
#   'bmi': 30.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4646.76},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1fc'),
#   'age': 21,
#   'sex': 'female',
#   'bmi': 35.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2404.73},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1fd'),
#   'age': 52,
#   'sex': 'male',
#   'bmi': 32.2,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 11488.32},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1fe'),
#   'age': 60,
#   'sex': 'male',
#   'bmi': 28.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 30260.0},
#  {'_id': ObjectId('6558c4c5d93220317ba8a1ff'),
#   'age': 58,
#   'sex': 'male',
#   'bmi': 49.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11381.33},
#  {'_id': ObjectId('6558c4c5d93220317ba8a200'),
#   'age': 29,
#   'sex': 'female',
#   'bmi': 27.9,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 19107.78},
#  {'_id': ObjectId('6558c4c5d93220317ba8a201'),
#   'age': 49,
#   'sex': 'female',
#   'bmi': 27.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8601.33},
#  {'_id': ObjectId('6558c4c5d93220317ba8a202'),
#   'age': 37,
#   'sex': 'female',
#   'bmi': 23.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6686.43},
#  {'_id': ObjectId('6558c4c5d93220317ba8a203'),
#   'age': 44,
#   'sex': 'male',
#   'bmi': 37.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7740.34},
#  {'_id': ObjectId('6558c4c5d93220317ba8a204'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 23.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 1705.62},
#  {'_id': ObjectId('6558c4c5d93220317ba8a205'),
#   'age': 20,
#   'sex': 'female',
#   'bmi': 29.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2257.48},
#  {'_id': ObjectId('6558c4c5d93220317ba8a206'),
#   'age': 44,
#   'sex': 'male',
#   'bmi': 31.4,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 39556.49},
#  {'_id': ObjectId('6558c4c5d93220317ba8a207'),
#   'age': 47,
#   'sex': 'female',
#   'bmi': 33.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10115.01},
#  {'_id': ObjectId('6558c4c5d93220317ba8a208'),
#   'age': 26,
#   'sex': 'female',
#   'bmi': 28.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3385.4},
#  {'_id': ObjectId('6558c4c5d93220317ba8a209'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 28.3,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 17081.08},
#  {'_id': ObjectId('6558c4c5d93220317ba8a20a'),
#   'age': 52,
#   'sex': 'female',
#   'bmi': 37.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 9634.54},
#  {'_id': ObjectId('6558c4c5d93220317ba8a20b'),
#   'age': 32,
#   'sex': 'female',
#   'bmi': 17.8,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 32734.19},
#  {'_id': ObjectId('6558c4c5d93220317ba8a20c'),
#   'age': 38,
#   'sex': 'male',
#   'bmi': 34.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6082.41},
#  {'_id': ObjectId('6558c4c5d93220317ba8a20d'),
#   'age': 59,
#   'sex': 'female',
#   'bmi': 26.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 12815.44},
#  {'_id': ObjectId('6558c4c5d93220317ba8a20e'),
#   'age': 61,
#   'sex': 'female',
#   'bmi': 22.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13616.36},
#  {'_id': ObjectId('6558c4c5d93220317ba8a20f'),
#   'age': 53,
#   'sex': 'female',
#   'bmi': 35.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11163.57},
#  {'_id': ObjectId('6558c4c5d93220317ba8a210'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 25.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 1632.56},
#  {'_id': ObjectId('6558c4c5d93220317ba8a211'),
#   'age': 20,
#   'sex': 'female',
#   'bmi': 28.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2457.21},
#  {'_id': ObjectId('6558c4c5d93220317ba8a212'),
#   'age': 22,
#   'sex': 'female',
#   'bmi': 28.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2155.68},
#  {'_id': ObjectId('6558c4c5d93220317ba8a213'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 34.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1261.44},
#  {'_id': ObjectId('6558c4c5d93220317ba8a214'),
#   'age': 22,
#   'sex': 'male',
#   'bmi': 25.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2045.69},
#  {'_id': ObjectId('6558c4c5d93220317ba8a215'),
#   'age': 54,
#   'sex': 'female',
#   'bmi': 31.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 27322.73},
#  {'_id': ObjectId('6558c4c5d93220317ba8a216'),
#   'age': 22,
#   'sex': 'female',
#   'bmi': 36.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2166.73},
#  {'_id': ObjectId('6558c4c5d93220317ba8a217'),
#   'age': 34,
#   'sex': 'male',
#   'bmi': 22.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 27375.9},
#  {'_id': ObjectId('6558c4c5d93220317ba8a218'),
#   'age': 26,
#   'sex': 'male',
#   'bmi': 32.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3490.55},
#  {'_id': ObjectId('6558c4c5d93220317ba8a219'),
#   'age': 34,
#   'sex': 'male',
#   'bmi': 25.3,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 18972.5},
#  {'_id': ObjectId('6558c4c5d93220317ba8a21a'),
#   'age': 29,
#   'sex': 'male',
#   'bmi': 29.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 18157.88},
#  {'_id': ObjectId('6558c4c5d93220317ba8a21b'),
#   'age': 30,
#   'sex': 'male',
#   'bmi': 28.7,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 20745.99},
#  {'_id': ObjectId('6558c4c5d93220317ba8a21c'),
#   'age': 29,
#   'sex': 'female',
#   'bmi': 38.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5138.26},
#  {'_id': ObjectId('6558c4c5d93220317ba8a21d'),
#   'age': 46,
#   'sex': 'male',
#   'bmi': 30.5,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 40720.55},
#  {'_id': ObjectId('6558c4c5d93220317ba8a21e'),
#   'age': 51,
#   'sex': 'female',
#   'bmi': 37.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 9877.61},
#  {'_id': ObjectId('6558c4c5d93220317ba8a21f'),
#   'age': 53,
#   'sex': 'female',
#   'bmi': 37.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10959.69},
#  {'_id': ObjectId('6558c4c5d93220317ba8a220'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 28.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1842.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a221'),
#   'age': 35,
#   'sex': 'male',
#   'bmi': 24.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5125.22},
#  {'_id': ObjectId('6558c4c5d93220317ba8a222'),
#   'age': 48,
#   'sex': 'male',
#   'bmi': 29.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7789.64},
#  {'_id': ObjectId('6558c4c5d93220317ba8a223'),
#   'age': 32,
#   'sex': 'female',
#   'bmi': 37.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6334.34},
#  {'_id': ObjectId('6558c4c5d93220317ba8a224'),
#   'age': 42,
#   'sex': 'female',
#   'bmi': 23.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 19964.75},
#  {'_id': ObjectId('6558c4c5d93220317ba8a225'),
#   'age': 40,
#   'sex': 'female',
#   'bmi': 25.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7077.19},
#  {'_id': ObjectId('6558c4c5d93220317ba8a226'),
#   'age': 44,
#   'sex': 'male',
#   'bmi': 39.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6948.7},
#  {'_id': ObjectId('6558c4c5d93220317ba8a227'),
#   'age': 48,
#   'sex': 'male',
#   'bmi': 24.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 21223.68},
#  {'_id': ObjectId('6558c4c5d93220317ba8a228'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 25.2,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 15518.18},
#  {'_id': ObjectId('6558c4c5d93220317ba8a229'),
#   'age': 30,
#   'sex': 'male',
#   'bmi': 35.5,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 36950.26},
#  {'_id': ObjectId('6558c4c5d93220317ba8a22a'),
#   'age': 50,
#   'sex': 'female',
#   'bmi': 27.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 19749.38},
#  {'_id': ObjectId('6558c4c5d93220317ba8a22b'),
#   'age': 42,
#   'sex': 'female',
#   'bmi': 26.6,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 21348.71},
#  {'_id': ObjectId('6558c4c5d93220317ba8a22c'),
#   'age': 18,
#   'sex': 'female',
#   'bmi': 36.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 36149.48},
#  {'_id': ObjectId('6558c4c5d93220317ba8a22d'),
#   'age': 54,
#   'sex': 'male',
#   'bmi': 39.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10450.55},
#  {'_id': ObjectId('6558c4c5d93220317ba8a22e'),
#   'age': 32,
#   'sex': 'female',
#   'bmi': 29.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5152.13},
#  {'_id': ObjectId('6558c4c5d93220317ba8a22f'),
#   'age': 37,
#   'sex': 'male',
#   'bmi': 29.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5028.15},
#  {'_id': ObjectId('6558c4c5d93220317ba8a230'),
#   'age': 47,
#   'sex': 'male',
#   'bmi': 28.2,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 10407.09},
#  {'_id': ObjectId('6558c4c5d93220317ba8a231'),
#   'age': 20,
#   'sex': 'female',
#   'bmi': 37.0,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4830.63},
#  {'_id': ObjectId('6558c4c5d93220317ba8a232'),
#   'age': 32,
#   'sex': 'female',
#   'bmi': 33.2,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6128.8},
#  {'_id': ObjectId('6558c4c5d93220317ba8a233'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 31.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2719.28},
#  {'_id': ObjectId('6558c4c5d93220317ba8a234'),
#   'age': 27,
#   'sex': 'male',
#   'bmi': 18.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4827.9},
#  {'_id': ObjectId('6558c4c5d93220317ba8a235'),
#   'age': 63,
#   'sex': 'male',
#   'bmi': 41.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 13405.39},
#  {'_id': ObjectId('6558c4c5d93220317ba8a236'),
#   'age': 49,
#   'sex': 'male',
#   'bmi': 30.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 8116.68},
#  {'_id': ObjectId('6558c4c5d93220317ba8a237'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 16.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 1694.8},
#  {'_id': ObjectId('6558c4c5d93220317ba8a238'),
#   'age': 35,
#   'sex': 'female',
#   'bmi': 34.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5246.05},
#  {'_id': ObjectId('6558c4c5d93220317ba8a239'),
#   'age': 24,
#   'sex': 'female',
#   'bmi': 33.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2855.44},
#  {'_id': ObjectId('6558c4c5d93220317ba8a23a'),
#   'age': 63,
#   'sex': 'female',
#   'bmi': 37.7,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 48824.45},
#  {'_id': ObjectId('6558c4c5d93220317ba8a23b'),
#   'age': 38,
#   'sex': 'male',
#   'bmi': 27.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6455.86},
#  {'_id': ObjectId('6558c4c5d93220317ba8a23c'),
#   'age': 54,
#   'sex': 'male',
#   'bmi': 29.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10436.1},
#  {'_id': ObjectId('6558c4c5d93220317ba8a23d'),
#   'age': 46,
#   'sex': 'female',
#   'bmi': 28.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 8823.28},
#  {'_id': ObjectId('6558c4c5d93220317ba8a23e'),
#   'age': 41,
#   'sex': 'female',
#   'bmi': 33.2,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 8538.29},
#  {'_id': ObjectId('6558c4c5d93220317ba8a23f'),
#   'age': 58,
#   'sex': 'male',
#   'bmi': 28.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11735.88},
#  {'_id': ObjectId('6558c4c5d93220317ba8a240'),
#   'age': 18,
#   'sex': 'female',
#   'bmi': 38.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1631.82},
#  {'_id': ObjectId('6558c4c5d93220317ba8a241'),
#   'age': 22,
#   'sex': 'male',
#   'bmi': 20.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4005.42},
#  {'_id': ObjectId('6558c4c5d93220317ba8a242'),
#   'age': 44,
#   'sex': 'female',
#   'bmi': 26.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7419.48},
#  {'_id': ObjectId('6558c4c5d93220317ba8a243'),
#   'age': 44,
#   'sex': 'male',
#   'bmi': 30.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7731.43},
#  {'_id': ObjectId('6558c4c5d93220317ba8a244'),
#   'age': 36,
#   'sex': 'male',
#   'bmi': 41.9,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 43753.34},
#  {'_id': ObjectId('6558c4c5d93220317ba8a245'),
#   'age': 26,
#   'sex': 'female',
#   'bmi': 29.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3981.98},
#  {'_id': ObjectId('6558c4c5d93220317ba8a246'),
#   'age': 30,
#   'sex': 'female',
#   'bmi': 30.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5325.65},
#  {'_id': ObjectId('6558c4c5d93220317ba8a247'),
#   'age': 41,
#   'sex': 'female',
#   'bmi': 32.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6775.96},
#  {'_id': ObjectId('6558c4c5d93220317ba8a248'),
#   'age': 29,
#   'sex': 'female',
#   'bmi': 32.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4922.92},
#  {'_id': ObjectId('6558c4c5d93220317ba8a249'),
#   'age': 61,
#   'sex': 'male',
#   'bmi': 31.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12557.61},
#  {'_id': ObjectId('6558c4c5d93220317ba8a24a'),
#   'age': 36,
#   'sex': 'female',
#   'bmi': 26.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4883.87},
#  {'_id': ObjectId('6558c4c5d93220317ba8a24b'),
#   'age': 25,
#   'sex': 'male',
#   'bmi': 25.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2137.65},
#  {'_id': ObjectId('6558c4c5d93220317ba8a24c'),
#   'age': 56,
#   'sex': 'female',
#   'bmi': 26.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 12044.34},
#  {'_id': ObjectId('6558c4c5d93220317ba8a24d'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 34.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1137.47},
#  {'_id': ObjectId('6558c4c5d93220317ba8a24e'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 30.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 1639.56},
#  {'_id': ObjectId('6558c4c5d93220317ba8a24f'),
#   'age': 39,
#   'sex': 'female',
#   'bmi': 32.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5649.72},
#  {'_id': ObjectId('6558c4c5d93220317ba8a250'),
#   'age': 45,
#   'sex': 'female',
#   'bmi': 28.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8516.83},
#  {'_id': ObjectId('6558c4c5d93220317ba8a251'),
#   'age': 51,
#   'sex': 'female',
#   'bmi': 18.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 9644.25},
#  {'_id': ObjectId('6558c4c5d93220317ba8a252'),
#   'age': 64,
#   'sex': 'female',
#   'bmi': 39.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 14901.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a253'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 32.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2130.68},
#  {'_id': ObjectId('6558c4c5d93220317ba8a254'),
#   'age': 48,
#   'sex': 'female',
#   'bmi': 32.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8871.15},
#  {'_id': ObjectId('6558c4c5d93220317ba8a255'),
#   'age': 60,
#   'sex': 'female',
#   'bmi': 24.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 13012.21},
#  {'_id': ObjectId('6558c4c5d93220317ba8a256'),
#   'age': 27,
#   'sex': 'female',
#   'bmi': 36.1,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 37133.9},
#  {'_id': ObjectId('6558c4c5d93220317ba8a257'),
#   'age': 46,
#   'sex': 'male',
#   'bmi': 22.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7147.11},
#  {'_id': ObjectId('6558c4c5d93220317ba8a258'),
#   'age': 28,
#   'sex': 'female',
#   'bmi': 28.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4337.74},
#  {'_id': ObjectId('6558c4c5d93220317ba8a259'),
#   'age': 59,
#   'sex': 'male',
#   'bmi': 26.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11743.3},
#  {'_id': ObjectId('6558c4c5d93220317ba8a25a'),
#   'age': 35,
#   'sex': 'male',
#   'bmi': 27.7,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 20984.09},
#  {'_id': ObjectId('6558c4c5d93220317ba8a25b'),
#   'age': 63,
#   'sex': 'female',
#   'bmi': 31.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13880.95},
#  {'_id': ObjectId('6558c4c5d93220317ba8a25c'),
#   'age': 40,
#   'sex': 'male',
#   'bmi': 41.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6610.11},
#  {'_id': ObjectId('6558c4c5d93220317ba8a25d'),
#   'age': 20,
#   'sex': 'male',
#   'bmi': 33.0,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1980.07},
#  {'_id': ObjectId('6558c4c5d93220317ba8a25e'),
#   'age': 40,
#   'sex': 'male',
#   'bmi': 30.9,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8162.72},
#  {'_id': ObjectId('6558c4c5d93220317ba8a25f'),
#   'age': 24,
#   'sex': 'male',
#   'bmi': 28.5,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3537.7},
#  {'_id': ObjectId('6558c4c5d93220317ba8a260'),
#   'age': 34,
#   'sex': 'female',
#   'bmi': 26.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5002.78},
#  {'_id': ObjectId('6558c4c5d93220317ba8a261'),
#   'age': 45,
#   'sex': 'female',
#   'bmi': 30.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 8520.03},
#  {'_id': ObjectId('6558c4c5d93220317ba8a262'),
#   'age': 41,
#   'sex': 'female',
#   'bmi': 37.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7371.77},
#  {'_id': ObjectId('6558c4c5d93220317ba8a263'),
#   'age': 53,
#   'sex': 'female',
#   'bmi': 26.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10355.64},
#  {'_id': ObjectId('6558c4c5d93220317ba8a264'),
#   'age': 27,
#   'sex': 'male',
#   'bmi': 23.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2483.74},
#  {'_id': ObjectId('6558c4c5d93220317ba8a265'),
#   'age': 26,
#   'sex': 'female',
#   'bmi': 29.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3392.98},
#  {'_id': ObjectId('6558c4c5d93220317ba8a266'),
#   'age': 24,
#   'sex': 'female',
#   'bmi': 23.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 25081.77},
#  {'_id': ObjectId('6558c4c5d93220317ba8a267'),
#   'age': 34,
#   'sex': 'female',
#   'bmi': 33.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5012.47},
#  {'_id': ObjectId('6558c4c5d93220317ba8a268'),
#   'age': 53,
#   'sex': 'female',
#   'bmi': 33.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 10564.88},
#  {'_id': ObjectId('6558c4c5d93220317ba8a269'),
#   'age': 32,
#   'sex': 'male',
#   'bmi': 30.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5253.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a26a'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 34.8,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 34779.62},
#  {'_id': ObjectId('6558c4c5d93220317ba8a26b'),
#   'age': 42,
#   'sex': 'male',
#   'bmi': 24.6,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 19515.54},
#  {'_id': ObjectId('6558c4c5d93220317ba8a26c'),
#   'age': 55,
#   'sex': 'male',
#   'bmi': 33.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11987.17},
#  {'_id': ObjectId('6558c4c5d93220317ba8a26d'),
#   'age': 28,
#   'sex': 'male',
#   'bmi': 38.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2689.5},
#  {'_id': ObjectId('6558c4c5d93220317ba8a26e'),
#   'age': 58,
#   'sex': 'female',
#   'bmi': 41.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 24227.34},
#  {'_id': ObjectId('6558c4c5d93220317ba8a26f'),
#   'age': 41,
#   'sex': 'female',
#   'bmi': 31.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7358.18},
#  {'_id': ObjectId('6558c4c5d93220317ba8a270'),
#   'age': 47,
#   'sex': 'male',
#   'bmi': 25.5,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9225.26},
#  {'_id': ObjectId('6558c4c5d93220317ba8a271'),
#   'age': 42,
#   'sex': 'female',
#   'bmi': 36.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7443.64},
#  {'_id': ObjectId('6558c4c5d93220317ba8a272'),
#   'age': 59,
#   'sex': 'female',
#   'bmi': 27.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 14001.29},
#  {'_id': ObjectId('6558c4c5d93220317ba8a273'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 17.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1727.79},
#  {'_id': ObjectId('6558c4c5d93220317ba8a274'),
#   'age': 59,
#   'sex': 'male',
#   'bmi': 27.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12333.83},
#  {'_id': ObjectId('6558c4c5d93220317ba8a275'),
#   'age': 39,
#   'sex': 'male',
#   'bmi': 24.5,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6710.19},
#  {'_id': ObjectId('6558c4c5d93220317ba8a276'),
#   'age': 40,
#   'sex': 'female',
#   'bmi': 22.2,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 19444.27},
#  {'_id': ObjectId('6558c4c5d93220317ba8a277'),
#   'age': 18,
#   'sex': 'female',
#   'bmi': 26.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1615.77},
#  {'_id': ObjectId('6558c4c5d93220317ba8a278'),
#   'age': 31,
#   'sex': 'male',
#   'bmi': 38.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4463.21},
#  {'_id': ObjectId('6558c4c5d93220317ba8a279'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 29.1,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 17352.68},
#  {'_id': ObjectId('6558c4c5d93220317ba8a27a'),
#   'age': 44,
#   'sex': 'male',
#   'bmi': 38.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7152.67},
#  {'_id': ObjectId('6558c4c5d93220317ba8a27b'),
#   'age': 23,
#   'sex': 'female',
#   'bmi': 36.7,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 38511.63},
#  {'_id': ObjectId('6558c4c5d93220317ba8a27c'),
#   'age': 33,
#   'sex': 'female',
#   'bmi': 22.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 5354.07},
#  {'_id': ObjectId('6558c4c5d93220317ba8a27d'),
#   'age': 55,
#   'sex': 'female',
#   'bmi': 26.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 35160.13},
#  {'_id': ObjectId('6558c4c5d93220317ba8a27e'),
#   'age': 40,
#   'sex': 'male',
#   'bmi': 35.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7196.87},
#  {'_id': ObjectId('6558c4c5d93220317ba8a27f'),
#   'age': 63,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 29523.17},
#  {'_id': ObjectId('6558c4c5d93220317ba8a280'),
#   'age': 54,
#   'sex': 'male',
#   'bmi': 30.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 24476.48},
#  {'_id': ObjectId('6558c4c5d93220317ba8a281'),
#   'age': 60,
#   'sex': 'female',
#   'bmi': 38.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12648.7},
#  {'_id': ObjectId('6558c4c5d93220317ba8a282'),
#   'age': 24,
#   'sex': 'male',
#   'bmi': 35.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1986.93},
#  {'_id': ObjectId('6558c4c5d93220317ba8a283'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 20.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1832.09},
#  {'_id': ObjectId('6558c4c5d93220317ba8a284'),
#   'age': 29,
#   'sex': 'male',
#   'bmi': 29.0,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4040.56},
#  {'_id': ObjectId('6558c4c5d93220317ba8a285'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 17.3,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 12829.46},
#  {'_id': ObjectId('6558c4c5d93220317ba8a286'),
#   'age': 63,
#   'sex': 'female',
#   'bmi': 32.2,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 47305.31},
#  {'_id': ObjectId('6558c4c5d93220317ba8a287'),
#   'age': 54,
#   'sex': 'male',
#   'bmi': 34.2,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 44260.75},
#  {'_id': ObjectId('6558c4c5d93220317ba8a288'),
#   'age': 27,
#   'sex': 'male',
#   'bmi': 30.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4260.74},
#  {'_id': ObjectId('6558c4c5d93220317ba8a289'),
#   'age': 50,
#   'sex': 'male',
#   'bmi': 31.8,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 41097.16},
#  {'_id': ObjectId('6558c4c5d93220317ba8a28a'),
#   'age': 55,
#   'sex': 'female',
#   'bmi': 25.4,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13047.33},
#  {'_id': ObjectId('6558c4c5d93220317ba8a28b'),
#   'age': 56,
#   'sex': 'male',
#   'bmi': 33.6,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 43921.18},
#  {'_id': ObjectId('6558c4c5d93220317ba8a28c'),
#   'age': 38,
#   'sex': 'female',
#   'bmi': 40.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5400.98},
#  {'_id': ObjectId('6558c4c5d93220317ba8a28d'),
#   'age': 51,
#   'sex': 'male',
#   'bmi': 24.4,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11520.1},
#  {'_id': ObjectId('6558c4c5d93220317ba8a28e'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 31.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 33750.29},
#  {'_id': ObjectId('6558c4c5d93220317ba8a28f'),
#   'age': 58,
#   'sex': 'female',
#   'bmi': 25.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11837.16},
#  {'_id': ObjectId('6558c4c5d93220317ba8a290'),
#   'age': 20,
#   'sex': 'female',
#   'bmi': 26.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 17085.27},
#  {'_id': ObjectId('6558c4c5d93220317ba8a291'),
#   'age': 52,
#   'sex': 'male',
#   'bmi': 24.3,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 24869.84},
#  {'_id': ObjectId('6558c4c5d93220317ba8a292'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 37.0,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 36219.41},
#  {'_id': ObjectId('6558c4c5d93220317ba8a293'),
#   'age': 53,
#   'sex': 'female',
#   'bmi': 38.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 20463.0},
#  {'_id': ObjectId('6558c4c5d93220317ba8a294'),
#   'age': 46,
#   'sex': 'male',
#   'bmi': 42.4,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 46151.12},
#  {'_id': ObjectId('6558c4c5d93220317ba8a295'),
#   'age': 40,
#   'sex': 'male',
#   'bmi': 19.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 17179.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a296'),
#   'age': 59,
#   'sex': 'female',
#   'bmi': 32.4,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 14590.63},
#  {'_id': ObjectId('6558c4c5d93220317ba8a297'),
#   'age': 45,
#   'sex': 'male',
#   'bmi': 30.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7441.05},
#  {'_id': ObjectId('6558c4c5d93220317ba8a298'),
#   'age': 49,
#   'sex': 'male',
#   'bmi': 25.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9282.48},
# ...
#  {'_id': ObjectId('6558c4c5d93220317ba8a519'),
#   'age': 22,
#   'sex': 'male',
#   'bmi': 28.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2639.04},
#  {'_id': ObjectId('6558c4c5d93220317ba8a51a'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 31.7,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 33732.69},
#  {'_id': ObjectId('6558c4c5d93220317ba8a51b'),
#   'age': 59,
#   'sex': 'female',
#   'bmi': 26.7,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 14382.71},
#  {'_id': ObjectId('6558c4c5d93220317ba8a51c'),
#   'age': 44,
#   'sex': 'female',
#   'bmi': 27.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7626.99},
#  {'_id': ObjectId('6558c4c5d93220317ba8a51d'),
#   'age': 33,
#   'sex': 'male',
#   'bmi': 24.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5257.51},
#  {'_id': ObjectId('6558c4c5d93220317ba8a51e'),
#   'age': 24,
#   'sex': 'female',
#   'bmi': 34.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2473.33},
#  {'_id': ObjectId('6558c4c5d93220317ba8a51f'),
#   'age': 43,
#   'sex': 'female',
#   'bmi': 26.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 21774.32},
#  {'_id': ObjectId('6558c4c5d93220317ba8a520'),
#   'age': 45,
#   'sex': 'male',
#   'bmi': 22.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 35069.37},
#  {'_id': ObjectId('6558c4c5d93220317ba8a521'),
#   'age': 61,
#   'sex': 'female',
#   'bmi': 28.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13041.92},
#  {'_id': ObjectId('6558c4c5d93220317ba8a522'),
#   'age': 35,
#   'sex': 'female',
#   'bmi': 34.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5245.23},
#  {'_id': ObjectId('6558c4c5d93220317ba8a523'),
#   'age': 62,
#   'sex': 'female',
#   'bmi': 25.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13451.12},
#  {'_id': ObjectId('6558c4c5d93220317ba8a524'),
#   'age': 62,
#   'sex': 'female',
#   'bmi': 33.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13462.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a525'),
#   'age': 38,
#   'sex': 'male',
#   'bmi': 31.0,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5488.26},
#  {'_id': ObjectId('6558c4c5d93220317ba8a526'),
#   'age': 34,
#   'sex': 'male',
#   'bmi': 35.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4320.41},
#  {'_id': ObjectId('6558c4c5d93220317ba8a527'),
#   'age': 43,
#   'sex': 'male',
#   'bmi': 23.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6250.44},
#  {'_id': ObjectId('6558c4c5d93220317ba8a528'),
#   'age': 50,
#   'sex': 'male',
#   'bmi': 32.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 25333.33},
#  {'_id': ObjectId('6558c4c5d93220317ba8a529'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 23.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2913.57},
#  {'_id': ObjectId('6558c4c5d93220317ba8a52a'),
#   'age': 57,
#   'sex': 'female',
#   'bmi': 20.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12032.33},
#  {'_id': ObjectId('6558c4c5d93220317ba8a52b'),
#   'age': 62,
#   'sex': 'female',
#   'bmi': 39.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 13470.8},
#  {'_id': ObjectId('6558c4c5d93220317ba8a52c'),
#   'age': 41,
#   'sex': 'male',
#   'bmi': 34.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 6289.75},
#  {'_id': ObjectId('6558c4c5d93220317ba8a52d'),
#   'age': 26,
#   'sex': 'male',
#   'bmi': 46.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2927.06},
#  {'_id': ObjectId('6558c4c5d93220317ba8a52e'),
#   'age': 39,
#   'sex': 'female',
#   'bmi': 32.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6238.3},
#  {'_id': ObjectId('6558c4c5d93220317ba8a52f'),
#   'age': 46,
#   'sex': 'male',
#   'bmi': 25.8,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10096.97},
#  {'_id': ObjectId('6558c4c5d93220317ba8a530'),
#   'age': 45,
#   'sex': 'female',
#   'bmi': 35.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7348.14},
#  {'_id': ObjectId('6558c4c5d93220317ba8a531'),
#   'age': 32,
#   'sex': 'male',
#   'bmi': 37.2,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4673.39},
#  {'_id': ObjectId('6558c4c5d93220317ba8a532'),
#   'age': 59,
#   'sex': 'female',
#   'bmi': 27.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12233.83},
#  {'_id': ObjectId('6558c4c5d93220317ba8a533'),
#   'age': 44,
#   'sex': 'male',
#   'bmi': 29.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 32108.66},
#  {'_id': ObjectId('6558c4c5d93220317ba8a534'),
#   'age': 39,
#   'sex': 'female',
#   'bmi': 24.2,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8965.8},
#  {'_id': ObjectId('6558c4c5d93220317ba8a535'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 26.2,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2304.0},
#  {'_id': ObjectId('6558c4c5d93220317ba8a536'),
#   'age': 53,
#   'sex': 'male',
#   'bmi': 29.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 9487.64},
#  {'_id': ObjectId('6558c4c5d93220317ba8a537'),
#   'age': 18,
#   'sex': 'male',
#   'bmi': 23.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1121.87},
#  {'_id': ObjectId('6558c4c5d93220317ba8a538'),
#   'age': 50,
#   'sex': 'female',
#   'bmi': 46.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 9549.57},
#  {'_id': ObjectId('6558c4c5d93220317ba8a539'),
#   'age': 18,
#   'sex': 'female',
#   'bmi': 40.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2217.47},
#  {'_id': ObjectId('6558c4c5d93220317ba8a53a'),
#   'age': 19,
#   'sex': 'male',
#   'bmi': 22.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 1628.47},
#  {'_id': ObjectId('6558c4c5d93220317ba8a53b'),
#   'age': 62,
#   'sex': 'male',
#   'bmi': 39.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12982.87},
#  {'_id': ObjectId('6558c4c5d93220317ba8a53c'),
#   'age': 56,
#   'sex': 'female',
#   'bmi': 35.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11674.13},
#  {'_id': ObjectId('6558c4c5d93220317ba8a53d'),
#   'age': 42,
#   'sex': 'male',
#   'bmi': 35.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7160.09},
#  {'_id': ObjectId('6558c4c5d93220317ba8a53e'),
#   'age': 37,
#   'sex': 'male',
#   'bmi': 34.2,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 39047.29},
#  {'_id': ObjectId('6558c4c5d93220317ba8a53f'),
#   'age': 42,
#   'sex': 'male',
#   'bmi': 31.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6358.78},
#  {'_id': ObjectId('6558c4c5d93220317ba8a540'),
#   'age': 25,
#   'sex': 'male',
#   'bmi': 29.7,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 19933.46},
#  {'_id': ObjectId('6558c4c5d93220317ba8a541'),
#   'age': 57,
#   'sex': 'male',
#   'bmi': 18.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 11534.87},
#  {'_id': ObjectId('6558c4c5d93220317ba8a542'),
#   'age': 51,
#   'sex': 'male',
#   'bmi': 42.9,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 47462.89},
#  {'_id': ObjectId('6558c4c5d93220317ba8a543'),
#   'age': 30,
#   'sex': 'female',
#   'bmi': 28.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4527.18},
#  {'_id': ObjectId('6558c4c5d93220317ba8a544'),
#   'age': 44,
#   'sex': 'male',
#   'bmi': 30.2,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 38998.55},
#  {'_id': ObjectId('6558c4c5d93220317ba8a545'),
#   'age': 34,
#   'sex': 'male',
#   'bmi': 27.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 20009.63},
#  {'_id': ObjectId('6558c4c5d93220317ba8a546'),
#   'age': 31,
#   'sex': 'male',
#   'bmi': 39.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3875.73},
#  {'_id': ObjectId('6558c4c5d93220317ba8a547'),
#   'age': 54,
#   'sex': 'male',
#   'bmi': 30.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 41999.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a548'),
#   'age': 24,
#   'sex': 'male',
#   'bmi': 26.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 12609.89},
#  {'_id': ObjectId('6558c4c5d93220317ba8a549'),
#   'age': 43,
#   'sex': 'male',
#   'bmi': 35.0,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 41034.22},
#  {'_id': ObjectId('6558c4c5d93220317ba8a54a'),
#   'age': 48,
#   'sex': 'male',
#   'bmi': 36.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 28468.92},
#  {'_id': ObjectId('6558c4c5d93220317ba8a54b'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 39.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2730.11},
#  {'_id': ObjectId('6558c4c5d93220317ba8a54c'),
#   'age': 29,
#   'sex': 'female',
#   'bmi': 25.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 3353.28},
#  {'_id': ObjectId('6558c4c5d93220317ba8a54d'),
#   'age': 63,
#   'sex': 'female',
#   'bmi': 35.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 14474.68},
#  {'_id': ObjectId('6558c4c5d93220317ba8a54e'),
#   'age': 46,
#   'sex': 'male',
#   'bmi': 24.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9500.57},
#  {'_id': ObjectId('6558c4c5d93220317ba8a54f'),
#   'age': 52,
#   'sex': 'male',
#   'bmi': 36.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 26467.1},
#  {'_id': ObjectId('6558c4c5d93220317ba8a550'),
#   'age': 35,
#   'sex': 'male',
#   'bmi': 27.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4746.34},
#  {'_id': ObjectId('6558c4c5d93220317ba8a551'),
#   'age': 51,
#   'sex': 'male',
#   'bmi': 24.8,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 23967.38},
#  {'_id': ObjectId('6558c4c5d93220317ba8a552'),
#   'age': 44,
#   'sex': 'male',
#   'bmi': 25.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7518.03},
#  {'_id': ObjectId('6558c4c5d93220317ba8a553'),
#   'age': 21,
#   'sex': 'male',
#   'bmi': 25.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3279.87},
#  {'_id': ObjectId('6558c4c5d93220317ba8a554'),
#   'age': 39,
#   'sex': 'female',
#   'bmi': 34.3,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8596.83},
#  {'_id': ObjectId('6558c4c5d93220317ba8a555'),
#   'age': 50,
#   'sex': 'female',
#   'bmi': 28.2,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 10702.64},
#  {'_id': ObjectId('6558c4c5d93220317ba8a556'),
#   'age': 34,
#   'sex': 'female',
#   'bmi': 23.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4992.38},
#  {'_id': ObjectId('6558c4c5d93220317ba8a557'),
#   'age': 22,
#   'sex': 'female',
#   'bmi': 20.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2527.82},
#  {'_id': ObjectId('6558c4c5d93220317ba8a558'),
#   'age': 19,
#   'sex': 'female',
#   'bmi': 40.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1759.34},
#  {'_id': ObjectId('6558c4c5d93220317ba8a559'),
#   'age': 26,
#   'sex': 'male',
#   'bmi': 35.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2322.62},
#  {'_id': ObjectId('6558c4c5d93220317ba8a55a'),
#   'age': 29,
#   'sex': 'male',
#   'bmi': 22.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 16138.76},
#  {'_id': ObjectId('6558c4c5d93220317ba8a55b'),
#   'age': 48,
#   'sex': 'male',
#   'bmi': 40.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7804.16},
#  {'_id': ObjectId('6558c4c5d93220317ba8a55c'),
#   'age': 26,
#   'sex': 'male',
#   'bmi': 29.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2902.91},
#  {'_id': ObjectId('6558c4c5d93220317ba8a55d'),
#   'age': 45,
#   'sex': 'female',
#   'bmi': 40.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9704.67},
#  {'_id': ObjectId('6558c4c5d93220317ba8a55e'),
#   'age': 36,
#   'sex': 'female',
#   'bmi': 29.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4889.04},
#  {'_id': ObjectId('6558c4c5d93220317ba8a55f'),
#   'age': 54,
#   'sex': 'male',
#   'bmi': 25.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 25517.11},
#  {'_id': ObjectId('6558c4c5d93220317ba8a560'),
#   'age': 34,
#   'sex': 'male',
#   'bmi': 21.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4500.34},
#  {'_id': ObjectId('6558c4c5d93220317ba8a561'),
#   'age': 31,
#   'sex': 'male',
#   'bmi': 25.9,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 19199.94},
#  {'_id': ObjectId('6558c4c5d93220317ba8a562'),
#   'age': 27,
#   'sex': 'female',
#   'bmi': 30.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 16796.41},
#  {'_id': ObjectId('6558c4c5d93220317ba8a563'),
#   'age': 20,
#   'sex': 'male',
#   'bmi': 30.1,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4915.06},
#  {'_id': ObjectId('6558c4c5d93220317ba8a564'),
#   'age': 44,
#   'sex': 'female',
#   'bmi': 25.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7624.63},
#  {'_id': ObjectId('6558c4c5d93220317ba8a565'),
#   'age': 43,
#   'sex': 'male',
#   'bmi': 30.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8410.05},
#  {'_id': ObjectId('6558c4c5d93220317ba8a566'),
#   'age': 45,
#   'sex': 'female',
#   'bmi': 27.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 28340.19},
#  {'_id': ObjectId('6558c4c5d93220317ba8a567'),
#   'age': 34,
#   'sex': 'male',
#   'bmi': 34.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4518.83},
#  {'_id': ObjectId('6558c4c5d93220317ba8a568'),
#   'age': 24,
#   'sex': 'female',
#   'bmi': 20.5,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 14571.89},
#  {'_id': ObjectId('6558c4c5d93220317ba8a569'),
#   'age': 26,
#   'sex': 'female',
#   'bmi': 19.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 3378.91},
#  {'_id': ObjectId('6558c4c5d93220317ba8a56a'),
#   'age': 38,
#   'sex': 'female',
#   'bmi': 27.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7144.86},
#  {'_id': ObjectId('6558c4c5d93220317ba8a56b'),
#   'age': 50,
#   'sex': 'female',
#   'bmi': 31.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10118.42},
#  {'_id': ObjectId('6558c4c5d93220317ba8a56c'),
#   'age': 38,
#   'sex': 'male',
#   'bmi': 28.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5484.47},
#  {'_id': ObjectId('6558c4c5d93220317ba8a56d'),
#   'age': 27,
#   'sex': 'female',
#   'bmi': 20.0,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 16420.49},
#  {'_id': ObjectId('6558c4c5d93220317ba8a56e'),
#   'age': 39,
#   'sex': 'female',
#   'bmi': 23.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7986.48},
#  {'_id': ObjectId('6558c4c5d93220317ba8a56f'),
#   'age': 39,
#   'sex': 'female',
#   'bmi': 34.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7418.52},
#  {'_id': ObjectId('6558c4c5d93220317ba8a570'),
#   'age': 63,
#   'sex': 'female',
#   'bmi': 36.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 13887.97},
#  {'_id': ObjectId('6558c4c5d93220317ba8a571'),
#   'age': 33,
#   'sex': 'female',
#   'bmi': 36.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6551.75},
#  {'_id': ObjectId('6558c4c5d93220317ba8a572'),
#   'age': 36,
#   'sex': 'female',
#   'bmi': 26.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5267.82},
#  ...]

# %%
df=pd.DataFrame(data)

# %%
df.columns
# Out:
# Index([], dtype='object')

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.replace(to_replace='na',value=np.NAN,inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(df,test_size=0.2,random_state=1)

# %%
train
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 216    53  female  26.6         0     no  northwest  10355.64
# 731    53    male  21.4         1     no  southwest  10065.41
# 866    18    male  37.3         0     no  southeast   1141.45
# 202    60  female  24.0         0     no  northwest  13012.21
# 820    45    male  33.7         1     no  southwest   7445.92
# ...   ...     ...   ...       ...    ...        ...       ...
# 715    60    male  28.9         0     no  southwest  12146.97
# 905    26  female  29.4         2     no  northeast   4564.19
# 1096   51  female  35.0         2    yes  northeast  44641.20
# 235    40  female  22.2         2    yes  southeast  19444.27
# 1061   57    male  27.9         1     no  southeast  11554.22
#
# [1070 rows x 7 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11100/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
